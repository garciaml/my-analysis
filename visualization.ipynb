# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the tsv file to perorm the analysis
df = pd.read_csv("./derivatives fs_stats data-cortical_type-aparc_measure-area_hemi-lh.tsv", sep="\t", index_col=0)

# %%
# See how it looks like
print("There are", df.shape[0], "rows and", df.shape[1], "columns.")
df.head()
# Out:
# There are 226 rows and 37 columns.
#                lh_bankssts_area  lh_caudalanteriorcingulate_area  \
# lh.aparc.area
# sub-0001                 1584.0                            617.0
# sub-0002                 1019.0                            552.0
# sub-0003                  916.0                            506.0
# sub-0004                  905.0                            403.0
# sub-0005                 1096.0                            573.0
#
#                lh_caudalmiddlefrontal_area  lh_cuneus_area  \
# lh.aparc.area
# sub-0001                            1734.0          1642.0
# sub-0002                            2108.0          1625.0
# sub-0003                            1920.0          1064.0
# sub-0004                            1601.0          1255.0
# sub-0005                            2041.0          1493.0
#
#                lh_entorhinal_area  lh_fusiform_area  lh_inferiorparietal_area  \
# lh.aparc.area
# ...

# %%
# Let's visualize the distribution of each column
plt.figure(figsize=(16,9))
sns.boxplot(data=df.drop(["lh_WhiteSurfArea_area","BrainSegVolNotVent", "eTIV"], axis=1), orient="h")
plt.show()

plt.figure(figsize=(16,9))
sns.boxplot(data=df[["lh_WhiteSurfArea_area"]], orient="h")
plt.show()

plt.figure(figsize=(16,9))
sns.boxplot(data=df[["BrainSegVolNotVent", "eTIV"]], orient="h")
plt.show()

# %% [markdown]
# A change
